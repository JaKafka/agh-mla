# %%
import lstm.utilities as lsutil

import torch
import torch.nn as nn
import numpy as np

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.manual_seed(42)
np.random.seed(42)

df = lsutil.load_dataset_from_file("./data/AAPL.csv")
X_train, y_train, X_test, y_test = lsutil.process_dataset_dataframe(df, test_size=0.05)

# %%
import lstm.models as lsmodels

simple_regressor = lsmodels.SimpleLSTMRegressor().to(DEVICE)
training_data = lsutil.run_training_loop_MSE(DEVICE, simple_regressor, 50, X_train, y_train, X_test, y_test)

lsutil.print_train_summary_MSE(DEVICE, simple_regressor, training_data, X_train, y_train, X_test, y_test)
# Out:
# Starting training loop...
# Training loop finished!

# %%
larger_simple_regressor = lsmodels.SimpleLSTMRegressor(lstm_layers=2).to(DEVICE)
training_data = lsutil.run_training_loop_MSE(DEVICE, larger_simple_regressor, 50, X_train, y_train, X_test, y_test)

lsutil.print_train_summary_MSE(DEVICE, larger_simple_regressor, training_data, X_train, y_train, X_test, y_test)
# Out:
# Starting training loop...
# Training loop finished!

# %%
even_larger_simple_regressor = lsmodels.SimpleLSTMRegressor(lstm_layers=5).to(DEVICE)
training_data = lsutil.run_training_loop_MSE(DEVICE, even_larger_simple_regressor, 50, X_train, y_train, X_test, y_test)

lsutil.print_train_summary_MSE(DEVICE, even_larger_simple_regressor, training_data, X_train, y_train, X_test, y_test)
# Out:
# Starting training loop...
# Training loop finished!

# %%
even_larger_simple_regressor = lsmodels.SimpleLSTMRegressor(lstm_layers=5, hidden_size1=32).to(DEVICE)
training_data = lsutil.run_training_loop_MSE(DEVICE, even_larger_simple_regressor, 50, X_train, y_train, X_test, y_test)

lsutil.print_train_summary_MSE(DEVICE, even_larger_simple_regressor, training_data, X_train, y_train, X_test, y_test)
# Out:
# Starting training loop...
# Training loop finished!

# %%
even_larger_simple_regressor = lsmodels.SimpleLSTMRegressor(lstm_layers=5, hidden_size1=64).to(DEVICE)
training_data = lsutil.run_training_loop_MSE(DEVICE, even_larger_simple_regressor, 50, X_train, y_train, X_test, y_test)

lsutil.print_train_summary_MSE(DEVICE, even_larger_simple_regressor, training_data, X_train, y_train, X_test, y_test)
# Out:
# Starting training loop...
# Training loop finished!

# %%
even_larger_simple_regressor = lsmodels.SimpleLSTMRegressor(lstm_layers=5, hidden_size1=128).to(DEVICE)
training_data = lsutil.run_training_loop_MSE(DEVICE, even_larger_simple_regressor, 50, X_train, y_train, X_test, y_test)

lsutil.print_train_summary_MSE(DEVICE, even_larger_simple_regressor, training_data, X_train, y_train, X_test, y_test)
# Out:
# Starting training loop...
# Training loop finished!

# %%
even_larger_simple_regressor = lsmodels.SimpleLSTMRegressor(lstm_layers=3, hidden_size1=96).to(DEVICE)
training_data = lsutil.run_training_loop_MSE(DEVICE, even_larger_simple_regressor, 75, X_train, y_train, X_test, y_test)

lsutil.print_train_summary_MSE(DEVICE, even_larger_simple_regressor, training_data, X_train, y_train, X_test, y_test)
# Out:
# Starting training loop...
# Training loop finished!
